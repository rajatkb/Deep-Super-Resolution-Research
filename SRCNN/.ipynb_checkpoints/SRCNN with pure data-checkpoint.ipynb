# %% [markdown]
# #### This one will be last attempt at SCRNN to see what it can achive with a dataset
# #### That is not muddy just but only low resolution

# %%
import cv2
import os

# import argparse
# parser = argparse.ArgumentParser(description='control SRCNN')
# parser.add_argument('--to', action="store",dest="tryout", default=20)
# parser.add_argument('--ep', action="store",dest="epochs", default=50)
# parser.add_argument('--bs', action="store",dest="batch_size", default=64)
# parser.add_argument('--lr', action="store",dest="learning_rate", default=0.0001)
# parser.add_argument('--gpu', action="store",dest="gpu", default=1)

# values = parser.parse_args()
gpu=1
os.environ["CUDA_VISIBLE_DEVICES"]=str(gpu)

import sys
import numpy as np
import matplotlib.pyplot as plt
from CREATE_DATA_SET import PARSE_DATA
from keras.models import Model
from keras.layers import Input, Convolution2D
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from keras import backend as k
import tensorflow as tf

folder = '../sibling-face-data/DBs'
HEIGHT = 240
WIDTH = 320
CHANNEL = 3
pd = PARSE_DATA(folder  , WIDTH= WIDTH , HEIGHT=HEIGHT)

data = pd.get_augmented_data()
lr_data_2x = pd.get_downsample_2x_data()

print(data.shape)
print(lr_data_2x.shape)

def PSNRLoss(y_true, y_pred):
    return 10* k.log(k.mean(k.square(y_pred - y_true)))
# Out:
# (360, 240, 320, 3)
# (360, 120, 160, 3)

# %%
plt.imshow(data[0]) ## Pure High res data

# %%
plt.imshow(lr_data_2x[0]) ## pure 2x low res

# %%
class SRCNN:
    def __init__(self,width , height , channel , lr):
        self.height = height
        self.width = width
        inputs = Input(shape=(height, width , channel))
        x = Convolution2D(64, (9, 9), activation='relu', init='he_normal' , border_mode='same')(inputs)
        x = Convolution2D(32, (1, 1), activation='relu', init='he_normal' , border_mode='same')(x)
        x = Convolution2D(3, (5, 5), init='he_normal' , border_mode='same')(x)
        self.model = Model(input = inputs, output = x)
        adam = Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-8) 
        self.model.compile(loss='mse', optimizer=adam , metrics=[PSNRLoss])
        self.model.summary()
    
    def fit(self , X , Y ,batch_size=64 , epoch = 100 , gpu=0 ):
        X = np.array([cv2.resize(image, dsize=(self.width , self.height), interpolation=cv2.INTER_CUBIC) for image in X])
        # with tf.device('/gpu:'+str(gpu)):
        for i in range(epoch):    
            print("epoch: ",i)
            out = self.model.fit(X, Y , batch_size = batch_size , verbose =1 , nb_epoch=1)
            
    def get_model(self):
        return self.model

    def generate(self , X ):
        X = cv2.resize(X, dsize=(self.width , self.height), interpolation=cv2.INTER_CUBIC)
        return self.model.predict(np.array([X]))

# %%
learning_rate = 0.0001
batch_size = 64
epochs = 30
tryout = 10000

# %%
from PIL import Image

lr_data_8x = pd.get_8x_lower()
Y_data = pd.get_train_data()

model = SRCNN(WIDTH , HEIGHT , CHANNEL , learning_rate)

Image.fromarray(Y_data[0]).save("test_image.jpeg")
Image.fromarray(lr_data_2x[0]).save("test_image_2x_lower.jpeg")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 240, 320, 3)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 240, 320, 64)      15616
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 240, 320, 32)      2080
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 240, 320, 3)       2403
# =================================================================
# Total params: 20,099
# Trainable params: 20,099
# Non-trainable params: 0
# _________________________________________________________________
# /home/sanchit/anaconda/envs/rajat-py3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (9, 9), activation="relu", padding="same", kernel_initializer="he_normal")`
#
# /home/sanchit/anaconda/envs/rajat-py3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), activation="relu", padding="same", kernel_initializer="he_normal")`
#   import sys
# /home/sanchit/anaconda/envs/rajat-py3/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (5, 5), padding="same", kernel_initializer="he_normal")`
#
# /home/sanchit/anaconda/envs/rajat-py3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   if __name__ == '__main__':

# %%
def train(r):
    for i in range(tryout):
        print("tryout no: ",i)
        model.fit( lr_data_8x[:r], Y_data[:r] , epoch = epochs , batch_size=batch_size , gpu = gpu)
        im = model.generate(lr_data_2x[0])[0]
        Image.fromarray(im.astype('uint8')).save("generated_image_2x_"+str(i)+"_.jpeg")

# %%
train(10)

## THIS IS ON FINAL TRY WITH PURE DATA TO SEE WHETHER THE MAPPING OF MSE 
## FOR THIS FACIAL DATA FAILS OR NOT
## WHO NEEDS ADVERSARIAL ATTACKS WHEN LITTLE BIT OF NOISE CAN DESTROR YOUR MODEL
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-5f884f5751d7> in <module>()
# ----> 1 train(10)
#       2
#       3 ## THIS IS ON FINAL TRY WITH PURE DATA TO SEE WHETHER THE MAPPING OF MSE
#       4 ## FOR THIS FACIAL DATA FAILS OR NOT
#       5 ## WHO NEEDS ADVERSARIAL ATTACKS WHEN LITTLE BIT OF NOISE CAN DESTROR YOUR MODEL
#
# <ipython-input-74-64a44e82339e> in train(r)
#       1 def train(r):
# ----> 2         model.fit( lr_data_8x[:r], Y_data[:r] , epoch = epochs , batch_size=batch_size , gpu = gpu)
#       3         im = model.generate(lr_data_2x[0])[0]
#       4         Image.fromarray(im.astype('uint8')).save("generated_image_2x_"+str(i)+"_.jpeg")
#
# <ipython-input-67-415b8941e668> in fit(self, X, Y, batch_size, epoch, gpu)
#      15         X = np.array([cv2.resize(image, dsize=(self.width , self.height), interpolation=cv2.INTER_CUBIC) for image in X])
#      16         # with tf.device('/gpu:'+str(gpu)):
# ---> 17         for i in range(epoch):
#      18             print("epoch: ",i)
#      19             out = self.model.fit(X, Y , batch_size = batch_size , verbose =1 , nb_epoch=1)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### This to note that the images of generated_2x_22_.jpeg was based on batch size 32 loss 0.0001
# ### The second one i.e generated_2x_23_.jpeg is based on batch size 64 loss 0.0001
# ### We can see some significant difference between these two images ?????
# ### Whats fascinating is that structurally the image 23 is very much similar to the original image minus the texture . I think this is something worth noting. The reason being is the SUPER RESOLUTION PROBLEM OPTIMZATION IS HEAVILY AFFECTED BY THE NUMBER OF IMAGES TAKEN IN ONE BATCH ??

# %%
## Saving the model
md = model.get_model()

# %%
md.save_weights('SRCNN_proper_32x30_epochs.h5')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5a4caa4e0e00> in <module>()
#       1 from keras.models import load_model
# ----> 2 md = load_model('SRCNN_proper_32x30_epochs.h5')
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     288                           metrics=metrics,
#     289                           loss_weights=loss_weights,
# --> 290                           sample_weight_mode=sample_weight_mode)
#     291
#     292             # Set optimizer weights.
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#     437                 output_metrics = nested_metrics[i]
#     438                 output_weighted_metrics = nested_weighted_metrics[i]
# --> 439                 handle_metrics(output_metrics)
#     440                 handle_metrics(output_weighted_metrics, weights=weights)
#     441
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/engine/training.py in handle_metrics(metrics, weights)
#     394                     metric_name = metric_name_prefix + suffix
#     395                 else:
# --> 396                     metric_fn = metrics_module.get(metric)
#     397                     weighted_metric_fn = weighted_masked_objective(metric_fn)
#     398                     # Get metric name as string
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/metrics.py in get(identifier)
#      73         return deserialize(config)
#      74     elif isinstance(identifier, six.string_types):
# ---> 75         return deserialize(str(identifier))
#      76     elif callable(identifier):
#      77         return identifier
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/metrics.py in deserialize(config, custom_objects)
#      65                                     module_objects=globals(),
#      66                                     custom_objects=custom_objects,
# ---> 67                                     printable_module_name='metric function')
#      68
#      69
#
# ~/anaconda/envs/rajat-py3/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     163             if fn is None:
#     164                 raise ValueError('Unknown ' + printable_module_name +
# --> 165                                  ':' + function_name)
#     166         return fn
#     167     else:
#
# ValueError: Unknown metric function:PSNRLoss
